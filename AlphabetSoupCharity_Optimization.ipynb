# %% [markdown]
# Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")

from google.colab import drive
drive.mount('/content/drive')

from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/Colab Notebooks/deep-learning-challenge/AlphabetSoupCharity.h5')

application_df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns = ['EIN', 'NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df['APPLICATION_TYPE'].value_counts().reset_index()
app_type_count
# Out:
#    index  APPLICATION_TYPE
# 0     T3             27037
# 1     T4              1542
# 2     T6              1216
# 3     T5              1173
# 4    T19              1065
# 5     T8               737
# 6     T7               725
# 7    T10               528
# 8     T9               156
# 9    T13                66
# 10   T12                27
# 11    T2                16
# 12   T25                 3
# 13   T14                 3
# 14   T29                 2
# 15   T15                 2
# 16   T17                 1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = app_type_count[app_type_count['APPLICATION_TYPE'] <=156]['index']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classif_count = application_df['CLASSIFICATION'].value_counts()
classif_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
cleaned_class = classif_count.loc[classif_count >1]
cleaned_class
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classif_count.index.tolist()[5:]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df = pd.get_dummies(application_df)
app_dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Trying More Nodes

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 120
hidden_nodes_layer2 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 120)               5280
#
#  dense_1 (Dense)             (None, 50)                6050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 11381 (44.46 KB)
# Trainable params: 11381 (44.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5709 - accuracy: 0.7202
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7280
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7300
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7300
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7320
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7333
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7337
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5471 - accuracy: 0.7332
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7347
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7346
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7348
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7334
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7357
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7353
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7357
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5435 - accuracy: 0.7364
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7364
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7367
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7363
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7366
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7370
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7365
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7373
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7376
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7369
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5411 - accuracy: 0.7367
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5408 - accuracy: 0.7368
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5403 - accuracy: 0.7374
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7383
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7374
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7369
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7385
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7384
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7383
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7379
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7386
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7383
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7392
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7385
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7390
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7382
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7388
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7385
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5373 - accuracy: 0.7386
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7396
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7385
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7391
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7383
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7390
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7399
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7390
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7394
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7388
# Epoch 55/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7393
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7385
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7390
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7393
# Epoch 59/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7395
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7391
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7387
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7393
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7397
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7400
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7396
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5358 - accuracy: 0.7395
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7393
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7411
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7396
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7398
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7399
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5355 - accuracy: 0.7399
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7397
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7400
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7406
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7405
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7397
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7394
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7400
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5347 - accuracy: 0.7401
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7401
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7406
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7405
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7402
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7404
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7405
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7405

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5607 - accuracy: 0.7277 - 474ms/epoch - 2ms/step
# Loss: 0.560745120048523, Accuracy: 0.7276967763900757

# %% [markdown]
# # More Nodes & More Epochs

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 140
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 140)               6160
#
#  dense_22 (Dense)            (None, 30)                4230
#
#  dense_23 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 10421 (40.71 KB)
# Trainable params: 10421 (40.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7282
# Epoch 2/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5518 - accuracy: 0.7297
# Epoch 3/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5504 - accuracy: 0.7296
# Epoch 4/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5491 - accuracy: 0.7313
# Epoch 5/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7317
# Epoch 6/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5483 - accuracy: 0.7320
# Epoch 7/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7319
# Epoch 8/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7333
# Epoch 9/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7343
# Epoch 10/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7338
# Epoch 11/300
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5456 - accuracy: 0.7343
# Epoch 12/300
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7359
# Epoch 13/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7348
# Epoch 14/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7358
# Epoch 15/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7351
# Epoch 16/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7349
# Epoch 17/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7343
# Epoch 18/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7360
# Epoch 19/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7353
# Epoch 20/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7365
# Epoch 21/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5425 - accuracy: 0.7356
# Epoch 22/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7364
# Epoch 23/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5420 - accuracy: 0.7366
# Epoch 24/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7367
# Epoch 25/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7366
# Epoch 26/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7358
# Epoch 27/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7376
# Epoch 28/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5417 - accuracy: 0.7371
# Epoch 29/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7362
# Epoch 30/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7379
# Epoch 31/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7370
# Epoch 32/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7372
# Epoch 33/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7376
# Epoch 34/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7371
# Epoch 35/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7370
# Epoch 36/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7375
# Epoch 37/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7376
# Epoch 38/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7377
# Epoch 39/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5389 - accuracy: 0.7387
# Epoch 40/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7381
# Epoch 41/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7383
# Epoch 42/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7388
# Epoch 43/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7384
# Epoch 44/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7385
# Epoch 45/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7378
# Epoch 46/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7387
# Epoch 47/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7387
# Epoch 48/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5380 - accuracy: 0.7381
# Epoch 49/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 50/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7378
# Epoch 51/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7391
# Epoch 52/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5375 - accuracy: 0.7388
# Epoch 53/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7386
# Epoch 54/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7397
# Epoch 55/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7387
# Epoch 56/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7391
# Epoch 57/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7383
# Epoch 58/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7388
# Epoch 59/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7396
# Epoch 60/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7396
# Epoch 61/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7393
# Epoch 62/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7399
# Epoch 63/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7392
# Epoch 64/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.7398
# Epoch 65/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5368 - accuracy: 0.7388
# Epoch 66/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5358 - accuracy: 0.7395
# Epoch 67/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7393
# Epoch 68/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7399
# Epoch 69/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7385
# Epoch 70/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7397
# Epoch 71/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7389
# Epoch 72/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7402
# Epoch 73/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.7396
# Epoch 74/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5362 - accuracy: 0.7395
# Epoch 75/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7400
# Epoch 76/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 77/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7404
# Epoch 78/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7400
# Epoch 79/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7388
# Epoch 80/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7398
# Epoch 81/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7402
# Epoch 82/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7394
# Epoch 83/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7396
# Epoch 84/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7399
# Epoch 85/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7396
# Epoch 86/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7402
# Epoch 87/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7388
# Epoch 88/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7398
# Epoch 89/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7400
# Epoch 90/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7398
# Epoch 91/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7405
# Epoch 92/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7397
# Epoch 93/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5348 - accuracy: 0.7394
# Epoch 94/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7396
# Epoch 95/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 96/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7403
# Epoch 97/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7398
# Epoch 98/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7397
# Epoch 99/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7386
# Epoch 100/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 101/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7393
# Epoch 102/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 103/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 104/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7403
# Epoch 105/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7396
# Epoch 106/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7407
# Epoch 107/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 108/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7400
# Epoch 109/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7399
# Epoch 110/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5343 - accuracy: 0.7396
# Epoch 111/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7405
# Epoch 112/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7401
# Epoch 113/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7396
# Epoch 114/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7397
# Epoch 115/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7395
# Epoch 116/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7398
# Epoch 117/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 118/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7401
# Epoch 119/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7405
# Epoch 120/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5338 - accuracy: 0.7399
# Epoch 121/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7403
# Epoch 122/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7397
# Epoch 123/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7398
# Epoch 124/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7403
# Epoch 125/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7409
# Epoch 126/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 127/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7405
# Epoch 128/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7401
# Epoch 129/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5333 - accuracy: 0.7406
# Epoch 130/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7400
# Epoch 131/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7411
# Epoch 132/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7403
# Epoch 133/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7402
# Epoch 134/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7406
# Epoch 135/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7403
# Epoch 136/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7405
# Epoch 137/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 138/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7400
# Epoch 139/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 140/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7403
# Epoch 141/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7403
# Epoch 142/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7406
# Epoch 143/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7398
# Epoch 144/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7403
# Epoch 145/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7400
# Epoch 146/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7408
# Epoch 147/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7407
# Epoch 148/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7410
# Epoch 149/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7406
# Epoch 150/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 151/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7410
# Epoch 152/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7411
# Epoch 153/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7407
# Epoch 154/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7399
# Epoch 155/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7410
# Epoch 156/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7400
# Epoch 157/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 158/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7408
# Epoch 159/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7410
# Epoch 160/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7409
# Epoch 161/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7409
# Epoch 162/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7403
# Epoch 163/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7405
# Epoch 164/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5331 - accuracy: 0.7406
# Epoch 165/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5326 - accuracy: 0.7410
# Epoch 166/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5325 - accuracy: 0.7404
# Epoch 167/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7410
# Epoch 168/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7400
# Epoch 169/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7404
# Epoch 170/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 171/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7402
# Epoch 172/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7406
# Epoch 173/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7404
# Epoch 174/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7413
# Epoch 175/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 176/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 177/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7408
# Epoch 178/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7411
# Epoch 179/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 180/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7411
# Epoch 181/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7420
# Epoch 182/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7407
# Epoch 183/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7408
# Epoch 184/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7415
# Epoch 185/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7413
# Epoch 186/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7408
# Epoch 187/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7408
# Epoch 188/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 189/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7411
# Epoch 190/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7407
# Epoch 191/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7407
# Epoch 192/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7401
# Epoch 193/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 194/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7405
# Epoch 195/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7401
# Epoch 196/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7403
# Epoch 197/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7400
# Epoch 198/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7408
# Epoch 199/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 200/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7404
# Epoch 201/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7405
# Epoch 202/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7400
# Epoch 203/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5327 - accuracy: 0.7405
# Epoch 204/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5326 - accuracy: 0.7405
# Epoch 205/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7408
# Epoch 206/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7403
# Epoch 207/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7406
# Epoch 208/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7410
# Epoch 209/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 210/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7402
# Epoch 211/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7407
# Epoch 212/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7411
# Epoch 213/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7406
# Epoch 214/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7404
# Epoch 215/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7412
# Epoch 216/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7400
# Epoch 217/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7411
# Epoch 218/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7406
# Epoch 219/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 220/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7410
# Epoch 221/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7409
# Epoch 222/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7407
# Epoch 223/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7413
# Epoch 224/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7413
# Epoch 225/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7403
# Epoch 226/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7403
# Epoch 227/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 228/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7403
# Epoch 229/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7406
# Epoch 230/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7406
# Epoch 231/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7410
# Epoch 232/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7406
# Epoch 233/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7406
# Epoch 234/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 235/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7404
# Epoch 236/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7402
# Epoch 237/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7410
# Epoch 238/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7414
# Epoch 239/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7411
# Epoch 240/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7411
# Epoch 241/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5314 - accuracy: 0.7416
# Epoch 242/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7415
# Epoch 243/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 244/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7408
# Epoch 245/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7414
# Epoch 246/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7406
# Epoch 247/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7411
# Epoch 248/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7416
# Epoch 249/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7412
# Epoch 250/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 251/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7414
# Epoch 252/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7413
# Epoch 253/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7406
# Epoch 254/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7410
# Epoch 255/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7405
# Epoch 256/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 257/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7406
# Epoch 258/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7411
# Epoch 259/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7411
# Epoch 260/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7410
# Epoch 261/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7412
# Epoch 262/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7408
# Epoch 263/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7408
# Epoch 264/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7409
# Epoch 265/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7410
# Epoch 266/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7402
# Epoch 267/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5312 - accuracy: 0.7406
# Epoch 268/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7411
# Epoch 269/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7413
# Epoch 270/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7406
# Epoch 271/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7411
# Epoch 272/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7410
# Epoch 273/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7413
# Epoch 274/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7410
# Epoch 275/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7411
# Epoch 276/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7409
# Epoch 277/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7410
# Epoch 278/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7415
# Epoch 279/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7412
# Epoch 280/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7414
# Epoch 281/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7410
# Epoch 282/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7409
# Epoch 283/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7419
# Epoch 284/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7410
# Epoch 285/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5429 - accuracy: 0.7409
# Epoch 286/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7413
# Epoch 287/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5311 - accuracy: 0.7417
# Epoch 288/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7419
# Epoch 289/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7411
# Epoch 290/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7411
# Epoch 291/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7420
# Epoch 292/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7413
# Epoch 293/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7411
# Epoch 294/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7411
# Epoch 295/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7413
# Epoch 296/300
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7410
# Epoch 297/300
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7415
# Epoch 298/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 299/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7417
# Epoch 300/300
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7413

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5842 - accuracy: 0.7269 - 447ms/epoch - 2ms/step
# Loss: 0.5842390060424805, Accuracy: 0.7268804907798767

# %% [markdown]
# # Trying More Levels, Nodes, & Epochs

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies_df['IS_SUCCESSFUL']
X = app_dummies_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 60
hidden_nodes_layer3 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 100)               4400
#
#  dense_25 (Dense)            (None, 60)                6060
#
#  dense_26 (Dense)            (None, 20)                1220
#
#  dense_27 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 11701 (45.71 KB)
# Trainable params: 11701 (45.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=250)
# Out:
# Epoch 1/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5681 - accuracy: 0.7210
# Epoch 2/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7293
# Epoch 3/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7294
# Epoch 4/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7317
# Epoch 5/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5492 - accuracy: 0.7311
# Epoch 6/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7339
# Epoch 7/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7330
# Epoch 8/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7334
# Epoch 9/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7339
# Epoch 10/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7335
# Epoch 11/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7349
# Epoch 12/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7346
# Epoch 13/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5440 - accuracy: 0.7353
# Epoch 14/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5433 - accuracy: 0.7365
# Epoch 15/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7352
# Epoch 16/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7364
# Epoch 17/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7363
# Epoch 18/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5429 - accuracy: 0.7365
# Epoch 19/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7348
# Epoch 20/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7366
# Epoch 21/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7360
# Epoch 22/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5413 - accuracy: 0.7362
# Epoch 23/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5413 - accuracy: 0.7378
# Epoch 24/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5408 - accuracy: 0.7371
# Epoch 25/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7369
# Epoch 26/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7378
# Epoch 27/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7381
# Epoch 28/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7378
# Epoch 29/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7372
# Epoch 30/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5398 - accuracy: 0.7392
# Epoch 31/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5392 - accuracy: 0.7392
# Epoch 32/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7377
# Epoch 33/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7381
# Epoch 34/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7386
# Epoch 35/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7388
# Epoch 36/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7386
# Epoch 37/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7391
# Epoch 38/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7387
# Epoch 39/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5378 - accuracy: 0.7380
# Epoch 40/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5379 - accuracy: 0.7379
# Epoch 41/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7383
# Epoch 42/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7387
# Epoch 43/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7386
# Epoch 44/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7392
# Epoch 45/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7387
# Epoch 46/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7396
# Epoch 47/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7400
# Epoch 48/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5368 - accuracy: 0.7394
# Epoch 49/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7387
# Epoch 50/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7397
# Epoch 51/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7397
# Epoch 52/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7399
# Epoch 53/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7397
# Epoch 54/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7389
# Epoch 55/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7399
# Epoch 56/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 57/250
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5359 - accuracy: 0.7394
# Epoch 58/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7388
# Epoch 59/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7396
# Epoch 60/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7396
# Epoch 61/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7405
# Epoch 62/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7401
# Epoch 63/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 64/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5351 - accuracy: 0.7405
# Epoch 65/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5353 - accuracy: 0.7396
# Epoch 66/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7400
# Epoch 67/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7396
# Epoch 68/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7395
# Epoch 69/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 70/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7403
# Epoch 71/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7396
# Epoch 72/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7401
# Epoch 73/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7402
# Epoch 74/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5345 - accuracy: 0.7390
# Epoch 75/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7396
# Epoch 76/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 77/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7399
# Epoch 78/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7384
# Epoch 79/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7403
# Epoch 80/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 81/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7410
# Epoch 82/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7407
# Epoch 83/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7403
# Epoch 84/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 85/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7399
# Epoch 86/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 87/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 88/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7404
# Epoch 89/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7399
# Epoch 90/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5331 - accuracy: 0.7404
# Epoch 91/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7410
# Epoch 92/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5334 - accuracy: 0.7405
# Epoch 93/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7404
# Epoch 94/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7400
# Epoch 95/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7395
# Epoch 96/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7406
# Epoch 97/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7403
# Epoch 98/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7406
# Epoch 99/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7406
# Epoch 100/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5326 - accuracy: 0.7403
# Epoch 101/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7402
# Epoch 102/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7401
# Epoch 103/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7403
# Epoch 104/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7404
# Epoch 105/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7411
# Epoch 106/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7411
# Epoch 107/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7407
# Epoch 108/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 109/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5323 - accuracy: 0.7407
# Epoch 110/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7405
# Epoch 111/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7404
# Epoch 112/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7409
# Epoch 113/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7408
# Epoch 114/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7405
# Epoch 115/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7415
# Epoch 116/250
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 117/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5324 - accuracy: 0.7411
# Epoch 118/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7408
# Epoch 119/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 120/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7407
# Epoch 121/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7401
# Epoch 122/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7406
# Epoch 123/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7411
# Epoch 124/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7409
# Epoch 125/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7416
# Epoch 126/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5318 - accuracy: 0.7410
# Epoch 127/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7408
# Epoch 128/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7409
# Epoch 129/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7408
# Epoch 130/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7409
# Epoch 131/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7407
# Epoch 132/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7411
# Epoch 133/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7413
# Epoch 134/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5313 - accuracy: 0.7411
# Epoch 135/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 136/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7412
# Epoch 137/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7412
# Epoch 138/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7410
# Epoch 139/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7410
# Epoch 140/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7413
# Epoch 141/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7412
# Epoch 142/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7418
# Epoch 143/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7412
# Epoch 144/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5311 - accuracy: 0.7413
# Epoch 145/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7411
# Epoch 146/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7397
# Epoch 147/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7416
# Epoch 148/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 149/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7414
# Epoch 150/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7409
# Epoch 151/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7407
# Epoch 152/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7417
# Epoch 153/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5314 - accuracy: 0.7405
# Epoch 154/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7413
# Epoch 155/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 156/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7413
# Epoch 157/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7415
# Epoch 158/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7405
# Epoch 159/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7405
# Epoch 160/250
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5312 - accuracy: 0.7407
# Epoch 161/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5313 - accuracy: 0.7418
# Epoch 162/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7412
# Epoch 163/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7411
# Epoch 164/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7414
# Epoch 165/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7408
# Epoch 166/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7416
# Epoch 167/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7411
# Epoch 168/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5312 - accuracy: 0.7411
# Epoch 169/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5311 - accuracy: 0.7414
# Epoch 170/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 171/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7413
# Epoch 172/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7414
# Epoch 173/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7407
# Epoch 174/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7415
# Epoch 175/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7411
# Epoch 176/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7422
# Epoch 177/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5313 - accuracy: 0.7416
# Epoch 178/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5313 - accuracy: 0.7413
# Epoch 179/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7411
# Epoch 180/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7422
# Epoch 181/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7421
# Epoch 182/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7417
# Epoch 183/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7414
# Epoch 184/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7416
# Epoch 185/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7411
# Epoch 186/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5308 - accuracy: 0.7414
# Epoch 187/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7412
# Epoch 188/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7418
# Epoch 189/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7414
# Epoch 190/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7414
# Epoch 191/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7412
# Epoch 192/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7417
# Epoch 193/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7418
# Epoch 194/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7414
# Epoch 195/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7417
# Epoch 196/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5307 - accuracy: 0.7421
# Epoch 197/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7414
# Epoch 198/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7411
# Epoch 199/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7414
# Epoch 200/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7418
# Epoch 201/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7420
# Epoch 202/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7421
# Epoch 203/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7415
# Epoch 204/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5302 - accuracy: 0.7421
# Epoch 205/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5303 - accuracy: 0.7417
# Epoch 206/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7421
# Epoch 207/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7415
# Epoch 208/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7416
# Epoch 209/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7421
# Epoch 210/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7418
# Epoch 211/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7414
# Epoch 212/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7415
# Epoch 213/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5305 - accuracy: 0.7422
# Epoch 214/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7413
# Epoch 215/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7411
# Epoch 216/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7413
# Epoch 217/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7414
# Epoch 218/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7411
# Epoch 219/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7424
# Epoch 220/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7414
# Epoch 221/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5300 - accuracy: 0.7415
# Epoch 222/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5313 - accuracy: 0.7415
# Epoch 223/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5306 - accuracy: 0.7415
# Epoch 224/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7413
# Epoch 225/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7417
# Epoch 226/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7413
# Epoch 227/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7422
# Epoch 228/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7420
# Epoch 229/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7414
# Epoch 230/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5304 - accuracy: 0.7408
# Epoch 231/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5299 - accuracy: 0.7417
# Epoch 232/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7420
# Epoch 233/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7423
# Epoch 234/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7414
# Epoch 235/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7417
# Epoch 236/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7418
# Epoch 237/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7415
# Epoch 238/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7412
# Epoch 239/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5307 - accuracy: 0.7427
# Epoch 240/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5301 - accuracy: 0.7422
# Epoch 241/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7414
# Epoch 242/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7412
# Epoch 243/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7416
# Epoch 244/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7418
# Epoch 245/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7420
# Epoch 246/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7420
# Epoch 247/250
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7427
# Epoch 248/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5297 - accuracy: 0.7421
# Epoch 249/250
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5299 - accuracy: 0.7416
# Epoch 250/250
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5296 - accuracy: 0.7415

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6041 - accuracy: 0.7280 - 1s/epoch - 4ms/step
# Loss: 0.6041007041931152, Accuracy: 0.7280466556549072

# %%
nn.save('/content/drive/MyDrive/Colab Notebooks/deep-learning-challenge/AlphabetSoupCharity_Optimization.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
